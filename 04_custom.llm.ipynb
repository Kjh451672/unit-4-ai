# %%
import gpt_2_simple as gpt2

# %%
session = gpt2.start_tf_sess()

# %%
gpt2.finetune(
    session, 
	"brothership.txt", 
	model_name="124M", 
	steps=100, 
	run_name="custom_ai"
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732714464.030116 4612634 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00, 2096.10it/s]
# dataset has 2061 tokens
# Training...
# [1 | 22.05] loss=2.97 avg=2.97
# [2 | 42.94] loss=2.59 avg=2.78
# [3 | 63.23] loss=2.46 avg=2.67
# [4 | 82.83] loss=2.27 avg=2.57
# [5 | 102.56] loss=2.14 avg=2.48
# [6 | 121.71] loss=1.89 avg=2.38
# [7 | 139.80] loss=1.72 avg=2.28
# [8 | 157.66] loss=1.53 avg=2.19
# [9 | 176.13] loss=1.38 avg=2.09
# [10 | 194.00] loss=1.14 avg=1.99
# [11 | 211.31] loss=1.06 avg=1.90
# [12 | 228.65] loss=0.92 avg=1.82
# [13 | 246.39] loss=0.85 avg=1.74
# [14 | 263.65] loss=0.74 avg=1.66
# [15 | 281.86] loss=0.62 avg=1.59
# [16 | 299.73] loss=0.55 avg=1.52
# ...

# %%
gpt2.generate(session, prefix="Q: What is glohm?")
# Out:
# Q: What is glohm?
# A: Glohm is an energy that causes people to think sad or self-isolating thoughts.
#
# Q: What is glohm's cycle?
# A: The cycle of Glohm is a system that helps you get used to being sad or self-isolating thoughts.
#
# Q: What is frisbee?
# A: Frisbee is an area in the game that lets you choose from Yoshi's Island's friendly game bros, and boss battles.
#
# Q: What is RaynForst Island?
# A: RaynForst Island is an island with a big rain forest, and on this island, you save a few toads the ended up here after getting flung from the Mushroom Kingdom.
#
# Q: What is Merrygo Island?
# A: Merrygo Island is and island with the main focus being a circular maze that you can rotate and traverse through.
#
# Q: Where do you find Princess Peach?
# A: After navigating through the maze on Merrygo Island, you reunite with Princess Peach and bring her back to Shipshape.
#
# Q: Where do you find Willma's daughter?
# ...

# %%
gpt2.generate(session, prefix="Q: How do you use Clockout Blow?")
# Out:
# Q: How do you use Clockout Blow?
# A: Press A or B with the corresponding bro to swing thier hammers as they zoom around at warp speed, then for the final hit, press X.
#
# Q: How do you use Yoo-Who Cannon?
# A: Memorize the positions of Mario and Luigi in the 9 barrels, and press A or B when that barrel float up. Press X for the final hit to shoot out a giant bros ball that hits all enemies.
#
# Q: How do you use Max-Mix Vortex?
# A: Press A and B to toss fireballs and iceballs into the vortex. Then move it around with the left stick to sweep up enemies, than mash X to deal damage.
#
# Q: How do you use Conductor Conductor?
# A: Aim Mario at the satellites with the left stick to build up the conductor's power. Then aim the beam at the enemies with the left stick, and press X when both cursors overlap.
#
# Q: Where do you get Max-Mix Vortex?
# A: You get Max-Mix Vortex after getting Chilliam and Burnadette's bond.
#
# Q: Where do you get Conductor Conductor?
# ...

# %%
gpt2.generate(session, prefix="Q: Who is the main antagonist?")
# Out:
# Q: Who is the main antagonist?
# A: The main antagonist of the game is Zokket, who is really a corrupted Cozette. A.K.A., Connie's mentor.
#
# Q: Who are the main antagonist's lackeys?
# A: The three lackeys of the main antagonist are a group of three that call themselves the Extension Corps.
#
# Q: How many Bros. Attacks are in the game?
# A: There are 10 bros attacks in Mario & Luigi: Brothership.
#
# Q: What are battle plugs?
# A: Battle plugs are implemented into the battle system which either boost the bros during battle, making fights a lot easier.
#
# Q: Can you combine certain battle plugs?
# A: Certain battle plugs can be combined to create combos, making thier effects even stronger.
#
# Q: How do you use the green shell?
# A: Press A and B to kick the shell around with Mario and Luigi. Once Luigi kicks it for the last time, it sweeps across the screen hitting all enemies.
#
# Q: How do you use the red shell?
# ...

# %%
gpt2.generate(session, prefix="Q: On which island do you find princess peach?")
# Out:
# Q: On which island do you find princess peach?
# A: After navigating through the maze on Merrygo Island, you reunite with Princess Peach and bring her back to Shipshape.
#
# Q: Where do you find Willma's daughter?
# A: Ypu end up finding Willma's daughter Maykit on Twistee island, after restoring the Twistee tree.
#
# Q: What is the big cannon on Shipshape island for?
# A: The big cannon can be used to look at reefs, shoot to nearby islets, and shoot to drifting islands.
#
# Q: How many reefs are in the the game?
# A: There are 20 reefs in the game, with all of them in some way referencing previous Mario & Luigi games.
#
# Q: How do you move between linked islands?
# A: There is a pipe on Shipshape that lets you select which linked Island you want to go to, along with a golden pipe that can be used on linked islands for fast travel.
#
# Q: Who is the main antagonist of the game?
# ...

# %%
gpt2.generate(session, prefix="Q: Does a mushroom restore Mario or Luigi's HP?")
# Out:
# Q: Does a mushroom restore Mario or Luigi's HP?
# A: A mushroom is an item can be used to restore a certain amount of HP.
#
# Q: How do you use the green shell?
# A: Press A and B to kick the shell around with Mario and Luigi. Once Luigi kicks it for the last time, it sweeps across the screen hitting all enemies.
#
# Q: How do you use the red shell?
# A: Like the green shell, press A and B accordingly between Mario and Luigi. When mario kicks it for the last time, it lands a powerful blow on one enemy.
#
# Q: how do you use the Zapperator?
# A: Alternate pressing A and B as fast as you can, and when the thundercloud grows big enough, press X to deal damage to all enemies. Take too long and the attack will fail.
#
# Q: How do you use Hatch Me If You Can?
# A: Press A or B when the egg falls down. Press the button opposite form the button you first pressed, and when the egg flys up, aim with the left stick then spike the egg with both bros by pressing X.
#
# ...
